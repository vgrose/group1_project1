# %% [markdown]
# # Effect of Healthcare Quality on Happiness

# %% [markdown]
# ## Data Cleanup
#
#
# ### World Happiness Index Data Cleanup
#
# * Data source: The World Happiness Report, 2015-17.
# * Final data represents average happiness score, economy, and life expectancy for each country in 2015-17.

# %%
#Import Dependencies:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
from scipy import stats
from statistics import mean
from matplotlib import style
style.use('ggplot')

# %%
#Read happiness data csvs:
data2015 = pd.read_csv("Resources/2015.csv")
data2016 = pd.read_csv("Resources/2016.csv")
data2017 = pd.read_csv("Resources/2017.csv")

#Clean 2015:
data2015_c = data2015[["Country", "Region", "Happiness Rank", "Happiness Score", "Economy (GDP per Capita)", "Health (Life Expectancy)"]]
data2015_c.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)  Health (Life Expectancy)
# 0                   1.39651                   0.94143
# 1                   1.30232                   0.94784
# 2                   1.32548                   0.87464
# 3                   1.45900                   0.88521
# 4                   1.32629                   0.90563

# %%
#Clean 2016:
data2016_c = data2016[["Country", "Region", "Happiness Rank", "Happiness Score", "Economy (GDP per Capita)", "Health (Life Expectancy)"]]
data2016_c.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Economy (GDP per Capita)  Health (Life Expectancy)
# 0                   1.44178                   0.79504
# 1                   1.52733                   0.86303
# 2                   1.42666                   0.86733
# 3                   1.57744                   0.79579
# 4                   1.40598                   0.81091

# %%
#Clean 2017:
data2017_c = data2017[["Country", "Happiness.Rank", "Happiness.Score", "Economy..GDP.per.Capita.","Health..Life.Expectancy."]]
data2017_c = data2017_c.rename(columns={"Happiness.Rank":"Happiness Rank",
                                       "Happiness.Score": "Happiness Score",
                                       "Economy..GDP.per.Capita.": "Economy (GDP per Capita)",
                                        "Health..Life.Expectancy.": "Health (Life Expectancy)"})
data2017_c.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0       Norway               1            7.537                  1.616463
# 1      Denmark               2            7.522                  1.482383
# 2      Iceland               3            7.504                  1.480633
# 3  Switzerland               4            7.494                  1.564980
# 4      Finland               5            7.469                  1.443572
#
#    Health (Life Expectancy)
# 0                  0.796667
# 1                  0.792566
# 2                  0.833552
# 3                  0.858131
# 4                  0.809158

# %%
#Merging datasets from years 2015, 2016, 2017
combined_happiness = pd.merge(data2015_c, data2016_c, on="Country", how = "left")
combined_happiness = pd.merge(combined_happiness, data2017_c, on="Country", how = "left")
combined_happiness.head()
# Out:
#        Country        Region_x  Happiness Rank_x  Happiness Score_x  \
# 0  Switzerland  Western Europe                 1              7.587
# 1      Iceland  Western Europe                 2              7.561
# 2      Denmark  Western Europe                 3              7.527
# 3       Norway  Western Europe                 4              7.522
# 4       Canada   North America                 5              7.427
#
#    Economy (GDP per Capita)_x  Health (Life Expectancy)_x        Region_y  \
# 0                     1.39651                     0.94143  Western Europe
# 1                     1.30232                     0.94784  Western Europe
# 2                     1.32548                     0.87464  Western Europe
# 3                     1.45900                     0.88521  Western Europe
# 4                     1.32629                     0.90563   North America
#
#    Happiness Rank_y  Happiness Score_y  Economy (GDP per Capita)_y  \
# ...

# %%
#Calculate average happiness, GDP, and life expectancy over three years

combined_happiness["Average Happiness"]=combined_happiness.loc[:, ["Happiness Score_x", "Happiness Score_y", "Happiness Score"]].mean(axis=1)
combined_happiness["Average GDP (per capita)"]=combined_happiness.loc[:, ["Economy (GDP per Capita)_x", "Economy (GDP per Capita)_y", "Economy (GDP per Capita)"]].mean(axis=1)
combined_happiness["Average Health (Life Expectancy)"]=combined_happiness.loc[:, ["Health (Life Expectancy)_x", "Health (Life Expectancy)_y", "Health (Life Expectancy)"]].mean(axis=1)

combined_happiness.head()
# Out:
#        Country        Region_x  Happiness Rank_x  Happiness Score_x  \
# 0  Switzerland  Western Europe                 1              7.587
# 1      Iceland  Western Europe                 2              7.561
# 2      Denmark  Western Europe                 3              7.527
# 3       Norway  Western Europe                 4              7.522
# 4       Canada   North America                 5              7.427
#
#    Economy (GDP per Capita)_x  Health (Life Expectancy)_x        Region_y  \
# 0                     1.39651                     0.94143  Western Europe
# 1                     1.30232                     0.94784  Western Europe
# 2                     1.32548                     0.87464  Western Europe
# 3                     1.45900                     0.88521  Western Europe
# 4                     1.32629                     0.90563   North America
#
#    Happiness Rank_y  Happiness Score_y  Economy (GDP per Capita)_y  \
# ...

# %%
# Data clean up
happiness_cleaned = combined_happiness[["Happiness Rank_x","Country", "Region_x", "Average Happiness", "Average GDP (per capita)", "Average Health (Life Expectancy)"]]
happiness_cleaned=happiness_cleaned.rename(columns={"Happiness Rank_x":"Happiness Rank",
                                                    "Region_x": "Region"})

happiness_cleaned.head()
# Out:
#    Happiness Rank      Country          Region  Average Happiness  \
# 0               1  Switzerland  Western Europe           7.530000
# 1               2      Iceland  Western Europe           7.522000
# 2               3      Denmark  Western Europe           7.525000
# 3               4       Norway  Western Europe           7.519000
# 4               5       Canada   North America           7.382333
#
#    Average GDP (per capita)  Average Health (Life Expectancy)
# 0                  1.496273                          0.887530
# 1                  1.403204                          0.882907
# 2                  1.416548                          0.820749
# 3                  1.550968                          0.825889
# 4                  1.415215                          0.855929

# %% [markdown]
# ### World Medical Expense Data Cleanup
#
# * Datasource: Global Health Expenditure Database from the World Bank
# * Data represents average medical expenses from 2005-15, in % GDP. We want to examine the effect of long-term medical expenditure on happiness level.

# %%
#read healthcare csv:
healthcare = pd.read_csv("Resources/Healthcare_cost.csv")

#Drop rows with NaN values
healthcare = healthcare.dropna(how='any')

#Clean up rows
healthcare = healthcare.drop("Indicator Name", axis=1)
healthcare.head()
# Out:
#   Country Name Country Code      2005       2006      2007       2008  \
# 1  Afghanistan          AFG  9.948289  10.622766  9.904674  10.256496
# 2       Angola          AGO  3.976992   3.600971  3.216291   3.499375
# 3      Albania          ALB  6.342830   5.932672  6.129000   5.582805
# 4      Andorra          AND  9.778755   9.713320  9.808338  10.432809
# 5   Arab World          ARB  3.497051   3.471659  3.563069   3.379315
#
#         2009       2010       2011       2012       2013       2014       2015
# 1   9.818487   8.569671   8.561907   7.897168   8.805964   9.652356  10.297595
# 2   3.584522   2.741499   2.843139   2.664953   2.992699   2.799603   2.946978
# 3   5.102306   5.034761   5.634350   5.860722   6.343861   6.956532   6.824439
# 4  10.895869  11.566204  11.825641  12.090213  14.158376  12.030786  11.974776
# 5   4.384158   3.971062   3.947312   4.078136   4.243065   4.517421   4.896603

# %%
#Compute average medical expenditure from 2005-2015 (%GDP)
healthcare["Avg Med Expense (%GDP)"] = healthcare[healthcare.columns].mean(axis=1)

#Final dataframe
healthcare_cleaned = healthcare[["Country Name", "Avg Med Expense (%GDP)"]]
healthcare_cleaned = healthcare_cleaned.dropna(how='any')
healthcare_cleaned.head()
# Out:
#   Country Name  Avg Med Expense (%GDP)
# 1  Afghanistan                9.485034
# 2       Angola                3.169729
# 3      Albania                5.976753
# 4      Andorra               11.297735
# 5   Arab World                3.995350

# %%
#Merge happiness data and health expenditure data
#Remove duplicated items and extra country name column
main= pd.merge(happiness_cleaned, healthcare_cleaned, how = "left", left_on="Country", right_on="Country Name")
main.drop_duplicates()
del main["Country Name"]
main.head()
# Out:
#    Happiness Rank      Country          Region  Average Happiness  \
# 0               1  Switzerland  Western Europe           7.530000
# 1               2      Iceland  Western Europe           7.522000
# 2               3      Denmark  Western Europe           7.525000
# 3               4       Norway  Western Europe           7.519000
# 4               5       Canada   North America           7.382333
#
#    Average GDP (per capita)  Average Health (Life Expectancy)  \
# 0                  1.496273                          0.887530
# 1                  1.403204                          0.882907
# 2                  1.416548                          0.820749
# 3                  1.550968                          0.825889
# 4                  1.415215                          0.855929
#
#    Avg Med Expense (%GDP)
# 0               10.684475
# 1                8.805395
# 2                9.946544
# 3                8.733094
# 4                9.922895

# %% [markdown]
# ### Healthcare Resources Data Cleanup
#
# * Data source: World Development Indicators from the World Bank.
# * Data from years 2015-17 were used to match the timeframe of happiness index data.

# %%
#Read and clean up data 

healthdata= pd.read_csv("Resources/healthdata.csv")
healthdata.dropna(how='any')
healthdata=healthdata.drop([0,1,2], axis=0).reset_index()
healthdata.columns=healthdata.iloc[0]
healthdata.reindex(healthdata.index.drop(0))
healthdata=healthdata.drop([0], axis=0).reset_index()
healthdata=healthdata.drop(columns="index")
healthdata=healthdata.drop(columns=3)

healthdata.head()
# Out:
# 0 Country Name Country Code                   Indicator Name         2005.0  \
# 0        Aruba          ABW    Population, male (% of total)      47.560683
# 1        Aruba          ABW                 Population, male   47575.000000
# 2        Aruba          ABW  Population, female (% of total)      52.439317
# 3        Aruba          ABW               Population, female   52456.000000
# 4        Aruba          ABW                Population, total  100031.000000
#
# 0         2006.0         2007.0        2008.0         2009.0         2010.0  \
# 0      47.540886      47.556903      47.60453      47.648572      47.671273
# 1   47936.000000   48137.000000   48249.00000   48341.000000   48467.000000
# 2      52.459114      52.443096      52.39547      52.351428      52.328727
# 3   52896.000000   53083.000000   53104.00000   53112.000000   53202.000000
# 4  100832.000000  101220.000000  101353.00000  101453.000000  101669.000000
#
# ...

# %%
#Select only data from 2015-17 to match happiness index dataset

healthdata=healthdata[["Country Name","Indicator Name", 2015.0, 2016.0, 2017.0]]
healthdata.round(2)
healthdata = healthdata.rename(columns={2015.0:"2015",
                                       2016.0:"2016",
                                       2017.0:"2017"})
healthdata.head()
# Out:
# 0 Country Name                   Indicator Name           2015           2016  \
# 0        Aruba    Population, male (% of total)      47.534479      47.508515
# 1        Aruba                 Population, male   49598.000000   49799.000000
# 2        Aruba  Population, female (% of total)      52.465521      52.491485
# 3        Aruba               Population, female   54743.000000   55023.000000
# 4        Aruba                Population, total  104341.000000  104822.000000
#
# 0           2017
# 0      47.482329
# 1   49982.000000
# 2      52.517671
# 3   55282.000000
# 4  105264.000000

# %%
#Compute sum over 2015-2017
healthdata["Sum"]= healthdata.loc[:, "2015":"2017"].sum(axis=1)
healthdata.head()
# Out:
# 0 Country Name                   Indicator Name           2015           2016  \
# 0        Aruba    Population, male (% of total)      47.534479      47.508515
# 1        Aruba                 Population, male   49598.000000   49799.000000
# 2        Aruba  Population, female (% of total)      52.465521      52.491485
# 3        Aruba               Population, female   54743.000000   55023.000000
# 4        Aruba                Population, total  104341.000000  104822.000000
#
# 0           2017            Sum
# 0      47.482329     142.525323
# 1   49982.000000  149379.000000
# 2      52.517671     157.474677
# 3   55282.000000  165048.000000
# 4  105264.000000  314427.000000

# %%
#Create new dataframe for groups of interest
#Number is per 1000 people in the population

physicians = healthdata.loc[healthdata["Indicator Name"]=="Physicians (per 1,000 people)"]
physicians = physicians[["Country Name", "Sum"]]
physicians = physicians.rename(columns={"Country Name": "Country",
                                        "Sum": "Number of physicians"})

nurses = healthdata.loc[healthdata["Indicator Name"]=="Nurses and midwives (per 1,000 people)"]
nurses = nurses[["Country Name", "Sum"]]
nurses = nurses.rename(columns={"Country Name": "Country",
                                "Sum": "Number of nurses and midwives"})

healthworkers = healthdata.loc[healthdata["Indicator Name"]=='Community health workers (per 1,000 people)']
healthworkers = healthworkers[["Country Name", "Sum"]]
healthworkers = healthworkers.rename(columns={"Country Name": "Country",
                                              "Sum": "Number of community health workers"})

beds = healthdata.loc[healthdata["Indicator Name"]=='Hospital beds (per 1,000 people)']
beds = beds[["Country Name", "Sum"]]
beds = beds.rename(columns={"Country Name": "Country",
                            "Sum": "Number of hospital beds"})

# %%
#Append to happiness dataframe
main=pd.merge(main, physicians, how='left', on = "Country")
main=pd.merge(main, nurses, how='left', on = "Country")
main=pd.merge(main, healthworkers, how='left', on = "Country")
main=pd.merge(main, beds, how='left', on = "Country")
main_with_nan=main.replace(0, "nan")
main.head()
# Out:
#    Happiness Rank      Country          Region  Average Happiness  \
# 0               1  Switzerland  Western Europe           7.530000
# 1               2      Iceland  Western Europe           7.522000
# 2               3      Denmark  Western Europe           7.525000
# 3               4       Norway  Western Europe           7.519000
# 4               5       Canada   North America           7.382333
#
#    Average GDP (per capita)  Average Health (Life Expectancy)  \
# 0                  1.496273                          0.887530
# 1                  1.403204                          0.882907
# 2                  1.416548                          0.820749
# 3                  1.550968                          0.825889
# 4                  1.415215                          0.855929
#
#    Avg Med Expense (%GDP)  Number of physicians  \
# 0               10.684475                 8.437
# 1                8.805395                 3.791
# ...

# %%
#Save the cleaned up data to csv
main.to_csv("Output/Maindata_cleaned.csv", encoding="utf-8", index=False)

# %% [markdown]
# ### Shapefile Data Cleanup for Map
#
# * Data source: https://www.naturalearthdata.com/downloads/10m-cultural-vectors/10m-admin-0-countries/

# %%
#read shapefile:
gdf = gpd.read_file("Resources/countries")

#Make dataframe of relevant columns:
gdf_short=gdf[["SOVEREIGNT", "geometry"]]

#Preview:
gdf_short.head()
# Out:
#   SOVEREIGNT                                           geometry
# 0  Indonesia  (POLYGON ((117.7036079039552 4.163414542001791...
# 1   Malaysia  (POLYGON ((117.7036079039552 4.163414542001791...
# 2      Chile  (POLYGON ((-69.51008875199994 -17.506588197999...
# 3    Bolivia  POLYGON ((-69.51008875199994 -17.5065881979999...
# 4       Peru  (POLYGON ((-69.51008875199994 -17.506588197999...

# %%
#data frame for heat map:
df=happiness_cleaned[["Country", "Average Happiness"]]
                     
#match country names:
df=df.replace("United States", "United States of America")
df=df.replace("Congo (Brazzaville)",'Republic of the Congo')
df=df.replace('Congo (Kinshasa)','Democratic Republic of the Congo')
df=df.replace('Czech Republic','Czechia')
df=df.replace('Serbia','Republic of Serbia')
df=df.replace('Tanzania','United Republic of Tanzania')

df.head()
# Out:
#        Country  Average Happiness
# 0  Switzerland           7.530000
# 1      Iceland           7.522000
# 2      Denmark           7.525000
# 3       Norway           7.519000
# 4       Canada           7.382333

# %%
#Merge data frame with shape info:
merged = gdf_short.merge(df, left_on='SOVEREIGNT', right_on='Country', how="outer")

#Preview:
merged.head()
# Out:
#   SOVEREIGNT                                           geometry    Country  \
# 0  Indonesia  (POLYGON ((117.7036079039552 4.163414542001791...  Indonesia
# 1   Malaysia  (POLYGON ((117.7036079039552 4.163414542001791...   Malaysia
# 2      Chile  (POLYGON ((-69.51008875199994 -17.506588197999...      Chile
# 3    Bolivia  POLYGON ((-69.51008875199994 -17.5065881979999...    Bolivia
# 4       Peru  (POLYGON ((-69.51008875199994 -17.506588197999...       Peru
#
#    Average Happiness
# 0           5.325000
# 1           5.953000
# 2           6.675667
# 3           5.845000
# 4           5.760667

# %% [markdown]
# ### Health Expenditure Data Cleanup
#
# * Data source:

# %%
#read data from World Bank
DGE_GDP = pd.read_csv("Resources/DGE GDP.csv")
DGE = pd.read_csv("Resources/DGE PPP.csv")
DPE = pd.read_csv("Resources/DPE PPP.csv")
OOP = pd.read_csv("Resources/OOP PPP.csv")

# %%
#Create  data2015 and data2016 with only relevant columns:

drop15 = ['Happiness Rank', 'Standard Error', 'Family', 'Health (Life Expectancy)',
          'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']
data2015.drop(columns = drop15, inplace = True)
data2015.head()
# Out:
#        Country          Region  Happiness Score  Economy (GDP per Capita)
# 0  Switzerland  Western Europe            7.587                   1.39651
# 1      Iceland  Western Europe            7.561                   1.30232
# 2      Denmark  Western Europe            7.527                   1.32548
# 3       Norway  Western Europe            7.522                   1.45900
# 4       Canada   North America            7.427                   1.32629

# %%
drop16 = ['Region', 'Happiness Rank', 'Lower Confidence Interval', 'Upper Confidence Interval',
          'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 
          'Generosity', 'Dystopia Residual']
data2016.drop(columns = drop16, inplace = True)
data2016.head()
# Out:
#        Country  Happiness Score  Economy (GDP per Capita)
# 0      Denmark            7.526                   1.44178
# 1  Switzerland            7.509                   1.52733
# 2      Iceland            7.501                   1.42666
# 3       Norway            7.498                   1.57744
# 4      Finland            7.413                   1.40598

# %%
#Merge data files

data_combined = pd.merge(data2015, data2016, on = "Country", suffixes=('_2015', '_2016'))
data_combined.head

#Save to a new csv file

data_combined.to_csv("Output/Clean Happiness Data.csv")

# %%
#Merge expenditure files

DGE_combined = pd.merge(DGE_GDP, DGE, on = 'Countries', suffixes=('_DGE', '_PPP'))
DGE_and_private = pd.merge(DGE_combined, DPE, on = 'Countries')
expenditure_data = pd.merge(DGE_and_private, OOP, on = 'Countries')
expenditure_data = expenditure_data.rename(columns={"Countries":"Country"})
expenditure_data.head

#Save to a new csv file

expenditure_data.to_csv('Output/Expenditure Data.csv')

# %%
#Merge new data and new expenditure files

happiness_expenditure = pd.merge(data_combined, expenditure_data, on = "Country")
happiness_expenditure = happiness_expenditure.dropna(how = "any")
happiness_expenditure.head()
# Out:
#        Country          Region  Happiness Score_2015  \
# 0  Switzerland  Western Europe                 7.587
# 1      Iceland  Western Europe                 7.561
# 2      Denmark  Western Europe                 7.527
# 3       Norway  Western Europe                 7.522
# 4       Canada   North America                 7.427
#
#    Economy (GDP per Capita)_2015  Happiness Score_2016  \
# 0                        1.39651                 7.509
# 1                        1.30232                 7.501
# 2                        1.32548                 7.526
# 3                        1.45900                 7.498
# 4                        1.32629                 7.404
#
#    Economy (GDP per Capita)_2016  \
# 0                        1.52733
# 1                        1.42666
# 2                        1.44178
# 3                        1.57744
# 4                        1.44015
#
#    2015 Domestic General Government Health Expenditure (GGHE-D) as % Gross Domestic Product (GDP)  \
# ...

# %% [markdown]
# ### Suicide Data Cleanup
#
# * Data source:

# %%
#Read suicide csv:

suicide_2017 = "Resources/Suicide_2017.csv"
suicide_2017_df = pd.read_csv(suicide_2017)
suicide_2017_df.head(10)
# Out:
#        Country  Both (s) Suicide/100k  M Suicide/100k  F Suicide/100k
# 0       Norway                   10.1            13.6             6.5
# 1      Denmark                    9.3            13.9             5.0
# 2      Iceland                   13.3            21.7             4.7
# 3  Switzerland                   11.3            15.8             6.9
# 4      Finland                   13.8            20.8             6.8
# 5  Netherlands                    9.6            12.9             6.4
# 6       Canada                   10.4            15.1             5.8
# 7  New Zealand                   11.6            17.3             6.2
# 8    Australia                   11.7            17.4             6.0
# 9       Sweden                   11.7            15.8             7.4

# %%
# Merge 2017 suicide and 2017 happiness
# Read CSV_2
happiness_2017 = "Resources/Country_happiness_2017.csv"
happiness_2017_df = pd.read_csv(happiness_2017)


country_data_df = pd.merge(suicide_2017_df,happiness_2017_df, how='outer', on='Country')
country_data_df.head(10)
# Out:
#        Country  Both (s) Suicide/100k  M Suicide/100k  F Suicide/100k  Year  \
# 0       Norway                   10.1            13.6             6.5  2017
# 1      Denmark                    9.3            13.9             5.0  2017
# 2      Iceland                   13.3            21.7             4.7  2017
# 3  Switzerland                   11.3            15.8             6.9  2017
# 4      Finland                   13.8            20.8             6.8  2017
# 5  Netherlands                    9.6            12.9             6.4  2017
# 6       Canada                   10.4            15.1             5.8  2017
# 7  New Zealand                   11.6            17.3             6.2  2017
# 8    Australia                   11.7            17.4             6.0  2017
# 9       Sweden                   11.7            15.8             7.4  2017
#
#    Hap_Score  Log GDP   HLEB  Perceptions of corruption  Positive affect  \
# ...

# %%
# Delete some columns
suicide_2017_df = country_data_df.drop(country_data_df.columns[[4,5,6,7,8,9,10]],1)
suicide_2017_df=suicide_2017_df.head(20)
suicide_2017_df.head()
# Out:
#        Country  Both (s) Suicide/100k  M Suicide/100k  F Suicide/100k
# 0       Norway                   10.1            13.6             6.5
# 1      Denmark                    9.3            13.9             5.0
# 2      Iceland                   13.3            21.7             4.7
# 3  Switzerland                   11.3            15.8             6.9
# 4      Finland                   13.8            20.8             6.8

# %%
#Read alcohol consumption csv:
alcohol_consumption_2017 = "Resources/Alcohol consumption_2017.csv"
alcohol_consumption_2017_df = pd.read_csv(alcohol_consumption_2017)
alcohol_consumption_2017_df.head(10)
# Out:
#        Country      Types  Lit_alc
# 0       Norway  All types    6.035
# 1      Denmark  All types    4.532
# 2      Iceland  All types    7.745
# 3  Switzerland  All types    6.256
# 4      Finland  All types    8.929
# 5  Netherlands  All types    5.029
# 6       Canada  All types    6.895
# 7  New Zealand  All types    7.023
# 8    Australia  All types    7.032
# 9       Sweden  All types    6.882

# %%
# Merge two alcohol and suicide data frames together
alcohol_suicide_df = pd.merge(suicide_2017_df,alcohol_consumption_2017_df, how='outer', on='Country')
alcohol_suicide_df.head(10)
# Out:
#        Country  Both (s) Suicide/100k  M Suicide/100k  F Suicide/100k  \
# 0       Norway                   10.1            13.6             6.5
# 1      Denmark                    9.3            13.9             5.0
# 2      Iceland                   13.3            21.7             4.7
# 3  Switzerland                   11.3            15.8             6.9
# 4      Finland                   13.8            20.8             6.8
# 5  Netherlands                    9.6            12.9             6.4
# 6       Canada                   10.4            15.1             5.8
# 7  New Zealand                   11.6            17.3             6.2
# 8    Australia                   11.7            17.4             6.0
# 9       Sweden                   11.7            15.8             7.4
#
#        Types  Lit_alc
# 0  All types    6.035
# 1  All types    4.532
# 2  All types    7.745
# 3  All types    6.256
# 4  All types    8.929
# 5  All types    5.029
# 6  All types    6.895
# ...

# %% [markdown]
# ## Data Analysis & Visualization
#
# ### Happiness by World Region 2015-17

# %% [markdown]
# ### Happiness Heat Map

# %%
#Set title:
title="Average Happiness Score 2015-2017"

#Set figure size, number of colors and color scheme:
figsize = (25, 16)
colors=12
cmap="viridis"

#Create color map:
ax=merged.dropna().plot(column="Average Happiness", cmap=cmap, figsize=figsize, scheme='equal_interval', k=colors, legend=True,  )

#Set N/A color: 
merged[merged.isna().any(axis=1)].plot(ax=ax, color='#fafafa', hatch='///')

#Remove axes:
ax.set_axis_off()

#Set Title:
ax.set_title(title, fontdict={'fontsize': 20}, loc='center')

#Move legend:
ax.get_legend().set_bbox_to_anchor((.12, .6))

#Save figure:
plt.savefig("Output/happiness_heatmap")

# %% [markdown]
# ### Happiness boxplot

# %%
#plot boxplot:
bxplot= sns.boxplot(x="Region",y="Average Happiness", data= happiness_cleaned, width =0.5)
bxplot= sns.stripplot(x="Region",y="Average Happiness", data= happiness_cleaned, jitter=True, marker='o', alpha = 0.3)
bxplot.set_xticklabels(bxplot.get_xticklabels(), rotation=40, ha="right")

#Set limits and title, layout
plt.ylim(2,8)
plt.title("Average Happiness by World Region between 2015-17")
plt.tight_layout()

#save figure
plt.savefig("Output/Avg Happiness Bxplot.png",bbox_inches= "tight")

# %% [markdown]
# ### Correlation heatmap

# %%
#keep only relevant columns:
main1 = main.drop(["Happiness Rank", "Average GDP (per capita)"],axis=1)

f, ax = plt.subplots(figsize=(10, 6))
corr = main1.corr()
hm = sns.heatmap(round(corr,2), annot=True, ax=ax, cmap="coolwarm",fmt='.2f',
                 linewidths=.05)
f.subplots_adjust(top=0.93)
t= f.suptitle('Correlation Heatmap for Happiness and Different Aspects of Healthcare Quality', fontsize=14)

plt.savefig("Output/Corr Heatmap.png",bbox_inches= "tight")

# %% [markdown]
# ### Medical Expense and happiness scatter plot

# %%
sns.set_style("ticks")

ax = sns.relplot(x="Avg Med Expense (%GDP)", y="Average Happiness", 
            size = "Average Health (Life Expectancy)", sizes = (10,350),
            alpha = 0.7, linewidth=0.8, edgecolor= None, data=main, height=6, hue='Region')

plt.xlim(0,18)
plt.ylim(2,8)

plt.title("Average Medical Expenses vs. Happiness")
plt.savefig("Output/Avg med expense v happiness.png",bbox_inches= "tight")

# %% [markdown]
# ### Number of physicians

# %%
sns.set_style("ticks")

ax = sns.relplot(x="Number of physicians", y="Average Happiness", 
                 alpha = 0.7, linewidth=0.8, edgecolor= "black", data=main_with_nan, height=6, hue='Region')

plt.title("Number of Physicians per 1,000 people vs. Happiness")
plt.savefig("Output/Physicians_scatter.png",bbox_inches= "tight")

# %%
bxplot= sns.boxplot(x="Region",y="Number of physicians", data= main, width =0.5)
bxplot.set_xticklabels(bxplot.get_xticklabels(), rotation=40, ha="right")

plt.title("Number of Physicians per 1,000 people")
plt.tight_layout()
plt.savefig("Output/Physicians_bx.png",bbox_inches= "tight")

# %% [markdown]
# ### Number of nurses/midwives

# %%
sns.set_style("ticks")

ax = sns.relplot(x="Number of nurses and midwives", y="Average Happiness", 
            alpha = 0.7, linewidth=0.8, edgecolor= "black", data=main_with_nan, height=6, hue='Region')


plt.title("Number of nurses and midwives per 1,000 people vs. Happiness")
plt.savefig("Output/Nurses_scatter.png",bbox_inches= "tight")

# %%
bxplot= sns.boxplot(x="Region",y="Number of nurses and midwives", data= main, width =0.5)
bxplot.set_xticklabels(bxplot.get_xticklabels(), rotation=40, ha="right")

plt.title("Number of nurses and midwives per 1,000 people")
plt.tight_layout()
plt.savefig("Output/Nurses_bx.png",bbox_inches= "tight")

# %% [markdown]
# ### Number of community health workers

# %%
sns.set_style("ticks")

ax = sns.relplot(x="Number of community health workers", y="Average Happiness", 
                 alpha = 0.7, linewidth=0.8, edgecolor= "black", data=main, height=6, hue='Region')

plt.title("Number of community health workers per 1,000 people vs. Happiness")
plt.savefig("Output/Healthworkers_scatter.png",bbox_inches= "tight")

# %%
bxplot= sns.boxplot(x="Region",y="Number of community health workers", data= main, width =0.5)
bxplot.set_xticklabels(bxplot.get_xticklabels(), rotation=40, ha="right")

plt.title("Number of community health workers per 1,000 people")
plt.tight_layout()
plt.savefig("Output/Healthworker_bx.png",bbox_inches= "tight")

# %% [markdown]
# ### Number of hospital beds

# %%
sns.set_style("ticks")

ax = sns.relplot(x="Number of hospital beds", y="Average Happiness", 
                 alpha = 0.7, linewidth=0.8, edgecolor= "black", data=main, height=6, hue='Region')

plt.title("Number of hospital beds per 1,000 people vs. Happiness")
plt.savefig("Output/Bed_scatter.png",bbox_inches= "tight")

# %%
bxplot= sns.boxplot(x="Region",y="Number of hospital beds", data= main, width =0.5)
bxplot.set_xticklabels(bxplot.get_xticklabels(), rotation=40, ha="right")

plt.title("Number of hospital beds per 1,000 people")
plt.tight_layout()
plt.savefig("Output/Bed_bx.png",bbox_inches= "tight")

# %% [markdown]
# ### Health expenditure vs. economy

# %%
#Create 2015 plots

plt.scatter(happiness_expenditure['2015 Domestic General Government Health Expenditure (GGHE-D) as % Gross Domestic Product (GDP)'],
            happiness_expenditure['Economy (GDP per Capita)_2015'], 
            edgecolor="black", linewidths=1, marker="o", alpha=0.8, color = 'g')

plt.title("2015 Government Health Expenditure vs. Economy")
plt.xlabel("Domestic General Government Health Expenditure (%GDP)")
plt.ylabel("Economy per Capita (GDP)")
plt.grid(True)
plt.xlim([-.5, 10])
plt.ylim([-.5, 2])

#save figure

plt.savefig("Output/2015 Economy vs. Govt.png")

#show plot

plt.show()

# %%
#Create 2016 plots

plt.scatter(happiness_expenditure['2016 Domestic General Government Health Expenditure (GGHE-D) as % Gross Domestic Product (GDP)'],
            happiness_expenditure['Economy (GDP per Capita)_2016'], 
            edgecolor="black", linewidths=1, marker="o", alpha=0.8, color = 'r')

plt.title("2016 Government Health Expenditure vs. Economy")
plt.xlabel("Domestic General Government Health Expenditure (%GDP)")
plt.ylabel("Economy per Capita (GDP)")
plt.grid(True)
plt.ylim([0, 2])
plt.xlim([-1, 11])

#save figure

plt.savefig("Output/2016 Economy vs. Govt.png")

#show plot

plt.show()

# %% [markdown]
# ### Private Health expenditure vs. happiness

# %%
#create 2015 plot:
plt.scatter(happiness_expenditure['2015 Domestic Private Health Expenditure (PVT-D) per Capita in PPP Int$'].str.replace(',','').astype(int), 
            happiness_expenditure['Happiness Score_2015'], edgecolor="black", linewidths=1, marker="o")

plt.title(f"2015 Happiness vs. Private Health Expenditure")
plt.ylabel("Happiness Score")
plt.xlabel("Private Health Expenditure per Capita (PPP Intl$)")
plt.xlim([0,3000])
plt.grid(True)

#save figure

plt.savefig("Output/2015 Happiness vs. PVT-D.png")

#show plot

plt.show()

# %%
#create 2016 plot:
plt.scatter(happiness_expenditure['2016 Domestic Private Health Expenditure (PVT-D) per Capita in PPP Int$'].str.replace(',','').astype(int), 
            happiness_expenditure['Happiness Score_2016'], edgecolor="black", linewidths=1, marker="o")

plt.title(f"2016 Happiness vs. Private Health Expenditure")
plt.ylabel("Happiness Score")
plt.xlabel("Private Health Expenditure per Capita (PPP Intl$)")
plt.xlim([0,3000])
plt.grid(True)

#save figure

plt.savefig("Output/2016 Happiness vs. PVT-D.png")

#show plot

plt.show()

# %% [markdown]
# ### Happiness vs out of pocket expenditure:

# %%
#create 2015 plot:
plt.scatter(happiness_expenditure['2015 Out-of-Pocket Expenditure (OOPS) per Capita in PPP Int$'].str.replace(',','').astype(int), 
            happiness_expenditure['Happiness Score_2015'], edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8)

plt.title(f"2015 Happiness vs. Out-of-Pocket Expenditure")
plt.ylabel("Happiness Score")
plt.xlabel("Out-of-Pocket Expenditure per Capita (PPP Intl$)")
plt.grid(True)
plt.xlim([0, 2500])
plt.ylim([0, 10])

#save figure

plt.savefig("Output/2015 Happiness vs. OOPS.png")

#show plot

plt.show()

# %%
#create 2016 plot:
plt.scatter(happiness_expenditure['2016 Out-of-Pocket Expenditure (OOPS) per Capita in PPP Int$'].str.replace(',','').astype(int), 
            happiness_expenditure['Happiness Score_2016'], edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8)

plt.title(f"2016 Happiness vs. Out-of-Pocket Expenditure")
plt.ylabel("Happiness Score")
plt.xlabel("Out-of-Pocket Expenditure per Capita (PPP Intl$)")
plt.grid(True)
plt.xlim([0, 2500])
plt.ylim([0, 10])

#save figure

plt.savefig("Output/2016 Happiness vs. OOPS.png")

#show plot

plt.show()

# %% [markdown]
# ### Happiness vs government health expenditure

# %%
#create 2015 plot
plt.scatter(happiness_expenditure['2015 Domestic General Government Health Expenditure (GGHE-D) per Capita in PPP Int$'].str.replace(',','').astype(int), 
            happiness_expenditure['Happiness Score_2015'], edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8)

plt.title(f"2015 Happiness vs. Government Health Expenditure")
plt.ylabel("Happiness Score")
plt.xlabel("Government Health Expenditure per Capita (PPP Intl$)")
plt.grid(True)
plt.xlim([0, 6000])
plt.ylim([0, 10])

#save figure

plt.savefig("Output/2015 Happiness vs. GGHE-D.png")

#show plot

plt.show()

# %%
#create 2016 plot
plt.scatter(happiness_expenditure['2016 Domestic General Government Health Expenditure (GGHE-D) per Capita in PPP Int$'].str.replace(',','').astype(int), 
            happiness_expenditure['Happiness Score_2016'], edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8)

plt.title(f"2016 Happiness vs. Government Health Expenditure")
plt.ylabel("Happiness Score")
plt.xlabel("Government Health Expenditure per Capita (PPP Intl$)")
plt.grid(True)
plt.xlim([0, 6000])
plt.ylim([0, 10])

#save figure

plt.savefig("Output/2016 Happiness vs. GGHE-D.png")

#show plot

plt.show()

# %% [markdown]
# ### Happiness, alcohol, and suicide

# %%
# Plot multiple column
suicide_plot =suicide_2017_df.plot(kind = "bar", figsize=(15, 5), colormap='Paired')

# Configure plot and ticks
suicide_plot.set_xticklabels(suicide_2017_df["Country"],rotation = 45)
      
plt.title("Suicide around the world - BIG-20")                            
                             
# Set a title for the chart
plt.savefig("Output/suicide-plot.png")
plt.show()
plt.tight_layout()

# %%
# Another plot - happiness around the world
## Filter the Data Frame down to those columns to chart
happiness_plot = happiness_2017_df[["Country", "Hap_Score"]]
happiness_plot = happiness_plot.set_index(["Country"])

happiness_plot.head()
happiness_plot.plot(kind = "bar", figsize=(15, 5))

# Set a title for the chart
plt.title("Happiness around the world- BIG-20")

# Show plot
plt.savefig("Output/hap_world-plot.png")
plt.show()
plt.tight_layout()

# %%
lit_alc = alcohol_consumption_2017_df.iloc[:, 2]
m_suicide = suicide_2017_df.iloc[:, 2]
m_suicide=m_suicide.head(20)
m_suicide
lit_alc
# Out:
# 0     6.035
# 1     4.532
# 2     7.745
# 3     6.256
# 4     8.929
# 5     5.029
# 6     6.895
# 7     7.023
# 8     7.032
# 9     6.882
# 10    3.009
# 11    4.051
# 12    6.415
# 13    8.801
# 14    6.289
# 15    5.999
# 16    9.045
# 17    6.302
# 18    4.418
# 19    5.808
# Name: Lit_alc, dtype: float64

# %%
# Plot
fig,(ax1) = plt.subplots(1, sharex=True)
fig.suptitle("Alcohol-Suicide(M)", fontsize=16, fontweight="bold")

ax1.set_xlim(min(lit_alc), max(lit_alc))
ax1.plot(lit_alc, m_suicide, linewidth=0, marker="o")

ax1.set_ylabel("Suiside per 100k (male)",fontsize = 16, fontweight="bold")
ax1.set_xlabel("Alcohol Consumption, L of pure alcohol",fontsize = 16, fontweight="bold")

# Set a title for the chart
plt.savefig("Output/correlation-plot.png")

# %%
xs = np.array([6.035,4.532,7.745,6.256,8.929,5.029,6.895,7.023,7.032,6.882,3.009,4.051,6.415,8.801,6.289,5.999,9.045,6.302,4.418,5.808],
dtype=np.float64)
ys = np.array([13.6 , 13.9, 21.7, 15.8, 20.8, 12.9, 15.1, 17.3, 17.4, 15.8, 8.20, 12.8, 17.5, 21.1, 17.6, 13.6, 22.2, 15, 11.9, 16], dtype=np.float64)

def best_fit_slope_and_intercept(xs,ys):
    m = (((mean(xs)*mean(ys)) - mean(xs*ys)) /
         ((mean(xs)*mean(xs)) - mean(xs*xs)))
    b = mean(ys) - m*mean(xs)
    return m, b

def squared_error(ys_orig,ys_line):
    return sum((ys_line - ys_orig) * (ys_line - ys_orig))

def coefficient_of_determination(ys_orig,ys_line):
    y_mean_line = [mean(ys_orig) for y in ys_orig]
    squared_error_regr = squared_error(ys_orig, ys_line)
    squared_error_y_mean = squared_error(ys_orig, y_mean_line)
    return 1 - (squared_error_regr/squared_error_y_mean)
    
m, b = best_fit_slope_and_intercept(xs,ys)
regression_line = [(m*x)+b for x in xs]

r_squared = coefficient_of_determination(ys,regression_line)
print("Coefficient of determination (r-squared) equals",r_squared)
# Out:
# Coefficient of determination (r-squared) equals 0.863732829587204
